# %% [markdown]
# # Crop Data Analysis

# %% [markdown]
# This project is about a graphical analysis of crop production in India, the crop data has been obtained from xyz.com , the major food in the data : Rice, Wheat, Coarse Cereals, Pulses, Vegetables,Fruits,Milk,Eggs,Fish and Meat,Oilseed,Sugarcane    Fibers.

# %%
import numpy as np                          #linear algebra
import pandas as pd                         #data processing
import matplotlib.pyplot as plt         
import matplotlib.patches as mpatches
import seaborn as sns
from IPython.display import display
# %matplotlib inline

# %%
from subprocess import check_output
display(check_output(["ls","input"]).decode("utf8"))
#Any results written to the current directory are saved as output
# Out:
# u'datafile (1).csv\ndatafile (2).csv\ndatafile (3).csv\ndatafile.csv\nproduce.csv\n'

# %%
crops_prod_data = pd.read_csv("input/datafile.csv", index_col='Crop')
display(crops_prod_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, Rice to nan
# Data columns (total 8 columns):
# 2004-05    12 non-null float64
# 2005-06    12 non-null float64
# 2006-07    12 non-null float64
# 2007-08    12 non-null float64
# 2008-09    12 non-null float64
# 2009-10    12 non-null float64
# 2010-11    12 non-null float64
# 2011-12    12 non-null float64
# dtypes: float64(8)
# memory usage: 936.0+ bytes
# None

# %%
display(crops_prod_data)
# Out:
#                      2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# Crop
# Rice                   100.0    101.0     99.0    105.0    112.0    121.0
# Wheat                  100.0    101.0    112.0    115.0    117.0    127.0
# Coarse Cereals         100.0    107.0    110.0    115.0    113.0    123.0
# Pulses                 100.0    108.0    134.0    124.0    124.0    146.0
# Vegetables             100.0    109.0    103.0    118.0    113.0    124.0
# Fruits                 100.0     99.0     99.0     98.0    102.0    104.0
# Milk                   100.0     97.0     98.0     98.0     98.0    112.0
# Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# Oilseeds               100.0     86.0     85.0     97.0    104.0    103.0
# Sugarcane              100.0     96.0     91.0     87.0     80.0     81.0
# Fibers                 100.0     92.0     91.0     96.0    109.0    107.0
# All Agriculture        100.0     99.0    101.0    104.0    106.0    115.0
# NaN                      NaN      NaN      NaN      NaN      NaN      NaN
#
#                      2010-11  2011-12
# Crop
# Rice                   117.0    110.0
# Wheat                  120.0    108.0
# Coarse Cereals         122.0    136.0
# Pulses                 137.0    129.0
# Vegetables             128.0    115.0
# Fruits                 114.0    119.0
# Milk                   123.0    124.0
# Eggs, Fish and Meat    133.0    137.0
# Oilseeds                99.0    102.0
# Sugarcane              109.0    107.0
# Fibers                 138.0    140.0
# All Agriculture        123.0    122.0
# NaN                      NaN      NaN

# %%
#drop all rows with NaN values
crops_prod_data = crops_prod_data.dropna()
display(crops_prod_data.index)
display(crops_prod_data.head())
# Out:
# Index([u'Rice', u'Wheat', u'Coarse Cereals', u'Pulses', u'Vegetables ',
#        u'Fruits', u'Milk', u'Eggs, Fish and Meat', u'Oilseeds', u'Sugarcane ',
#        u'Fibers', u'All Agriculture'],
#       dtype='object', name=u'Crop')
#                 2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  2010-11  \
# Crop
# Rice              100.0    101.0     99.0    105.0    112.0    121.0    117.0
# Wheat             100.0    101.0    112.0    115.0    117.0    127.0    120.0
# Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0    122.0
# Pulses            100.0    108.0    134.0    124.0    124.0    146.0    137.0
# Vegetables        100.0    109.0    103.0    118.0    113.0    124.0    128.0
#
#                 2011-12
# Crop
# Rice              110.0
# Wheat             108.0
# Coarse Cereals    136.0
# Pulses            129.0
# Vegetables        115.0

# %%
#plot for individual crops
crops_prod_data.loc['Rice', :].plot()
crops_prod_data.loc['Milk', :].plot()
crops_prod_data.loc['All Agriculture', :].plot()
plt.legend(loc='upper left')

# %%
#display index of dataframe 
display(crops_prod_data.index)
# Out:
# Index([u'Rice', u'Wheat', u'Coarse Cereals', u'Pulses', u'Vegetables ',
#        u'Fruits', u'Milk', u'Eggs, Fish and Meat', u'Oilseeds', u'Sugarcane ',
#        u'Fibers', u'All Agriculture'],
#       dtype='object', name=u'Crop')

# %%
#Transpose the dataset 
display(crops_prod_data.T)
# Out:
# Crop      Rice  Wheat  Coarse Cereals  Pulses  Vegetables   Fruits   Milk  \
# 2004-05  100.0  100.0           100.0   100.0        100.0   100.0  100.0
# 2005-06  101.0  101.0           107.0   108.0        109.0    99.0   97.0
# 2006-07   99.0  112.0           110.0   134.0        103.0    99.0   98.0
# 2007-08  105.0  115.0           115.0   124.0        118.0    98.0   98.0
# 2008-09  112.0  117.0           113.0   124.0        113.0   102.0   98.0
# 2009-10  121.0  127.0           123.0   146.0        124.0   104.0  112.0
# 2010-11  117.0  120.0           122.0   137.0        128.0   114.0  123.0
# 2011-12  110.0  108.0           136.0   129.0        115.0   119.0  124.0
#
# Crop     Eggs, Fish and Meat  Oilseeds  Sugarcane   Fibers  All Agriculture
# 2004-05                100.0     100.0       100.0   100.0            100.0
# 2005-06                102.0      86.0        96.0    92.0             99.0
# 2006-07                101.0      85.0        91.0    91.0            101.0
# 2007-08                100.0      97.0        87.0    96.0            104.0
# 2008-09                 99.0     104.0        80.0   109.0            106.0
# 2009-10                116.0     103.0        81.0   107.0            115.0
# 2010-11                133.0      99.0       109.0   138.0            123.0
# 2011-12                137.0     102.0       107.0   140.0            122.0

# %%
# Get current size of figure
fig_size = plt.rcParams["figure.figsize"]
display("Current size:", fig_size)

# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

#plot the transposed dataset
crops_prod_data.T.plot(subplots=True, layout=(3,4))
plt.xticks(rotation=45)
plt.tight_layout()
# Out:
# 'Current size:'
# [12.0, 9.0]

# %%
# dataset 2
cultivation_data = pd.read_csv("input/datafile (1).csv")
display(cultivation_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
# Crop                                     49 non-null object
# State                                    49 non-null object
# Cost of Cultivation (`/Hectare) A2+FL    49 non-null float64
# Cost of Cultivation (`/Hectare) C2       49 non-null float64
# Cost of Production (`/Quintal) C2        49 non-null float64
# Yield (Quintal/ Hectare)                 49 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 2.4+ KB
# None

# %%
display(cultivation_data.head())
display(cultivation_data.columns)
# Out:
#     Crop           State  Cost of Cultivation (`/Hectare) A2+FL  \
# 0  ARHAR   Uttar Pradesh                                9794.05
# 1  ARHAR       Karnataka                               10593.15
# 2  ARHAR         Gujarat                               13468.82
# 3  ARHAR  Andhra Pradesh                               17051.66
# 4  ARHAR     Maharashtra                               17130.55
#
#    Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 0                            23076.74                            1941.55
# 1                            16528.68                            2172.46
# 2                            19551.90                            1898.30
# 3                            24171.65                            3670.54
# 4                            25270.26                            2775.80
#
#    Yield (Quintal/ Hectare)   Per Hectare Cost Price  \
# 0                       9.83              19085.4365
# 1                       7.47              16228.2762
# 2                       9.59              18204.6970
# 3                       6.42              23564.8668
# 4                       8.72              24204.9760
#
#    Cost of cultivation per hectare  Yield in kg per hectare
# 0                         32870.79                    983.0
# 1                         27121.83                    747.0
# 2                         33020.72                    959.0
# 3                         41223.31                    642.0
# 4                         42400.81                    872.0
# Index([u'Crop', u'State', u'Cost of Cultivation (`/Hectare) A2+FL',
#        u'Cost of Cultivation (`/Hectare) C2',
#        u'Cost of Production (`/Quintal) C2', u'Yield (Quintal/ Hectare) ',
#        u'Per Hectare Cost Price', u'Cost of cultivation per hectare',
#        u'Yield in kg per hectare'],
#       dtype='object')

# %%
# Add additional columns in dataframe 
cultivation_data['Per Hectare Cost Price'] = cultivation_data['Cost of Production (`/Quintal) C2'] * cultivation_data['Yield (Quintal/ Hectare) ']
cultivation_data['Cost of cultivation per hectare'] = cultivation_data['Cost of Cultivation (`/Hectare) A2+FL'] + cultivation_data['Cost of Cultivation (`/Hectare) C2']
cultivation_data['Yield in kg per hectare'] = cultivation_data['Yield (Quintal/ Hectare) '] * 100
display(cultivation_data.head())
# Out:
#     Crop           State  Cost of Cultivation (`/Hectare) A2+FL  \
# 0  ARHAR   Uttar Pradesh                                9794.05
# 1  ARHAR       Karnataka                               10593.15
# 2  ARHAR         Gujarat                               13468.82
# 3  ARHAR  Andhra Pradesh                               17051.66
# 4  ARHAR     Maharashtra                               17130.55
#
#    Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 0                            23076.74                            1941.55
# 1                            16528.68                            2172.46
# 2                            19551.90                            1898.30
# 3                            24171.65                            3670.54
# 4                            25270.26                            2775.80
#
#    Yield (Quintal/ Hectare)   Per Hectare Cost Price  \
# 0                       9.83              19085.4365
# 1                       7.47              16228.2762
# 2                       9.59              18204.6970
# 3                       6.42              23564.8668
# 4                       8.72              24204.9760
#
#    Cost of cultivation per hectare  Yield in kg per hectare
# 0                         32870.79                    983.0
# 1                         27121.83                    747.0
# 2                         33020.72                    959.0
# 3                         41223.31                    642.0
# 4                         42400.81                    872.0

# %%
# checking transposed dataframe
display(cultivation_data.T.head())
# Out:
#                                                   0          1        2   \
# Crop                                           ARHAR      ARHAR    ARHAR
# State                                  Uttar Pradesh  Karnataka  Gujarat
# Cost of Cultivation (`/Hectare) A2+FL        9794.05    10593.1  13468.8
# Cost of Cultivation (`/Hectare) C2           23076.7    16528.7  19551.9
# Cost of Production (`/Quintal) C2            1941.55    2172.46   1898.3
#
#                                                    3            4   \
# Crop                                            ARHAR        ARHAR
# State                                  Andhra Pradesh  Maharashtra
# Cost of Cultivation (`/Hectare) A2+FL         17051.7      17130.5
# Cost of Cultivation (`/Hectare) C2            24171.7      25270.3
# Cost of Production (`/Quintal) C2             3670.54       2775.8
#
#                                                 5        6               7   \
# Crop                                        COTTON   COTTON          COTTON
# State                                  Maharashtra   Punjab  Andhra Pradesh
# Cost of Cultivation (`/Hectare) A2+FL      23711.4  29047.1         29140.8
# Cost of Cultivation (`/Hectare) C2         33116.8  50828.8         44756.7
# Cost of Production (`/Quintal) C2          2539.47  2003.76         2509.99
#
#                                             8        9     ...      \
# Crop                                    COTTON   COTTON    ...
# State                                  Gujarat  Haryana    ...
# Cost of Cultivation (`/Hectare) A2+FL  29616.1    29919    ...
# Cost of Cultivation (`/Hectare) C2     42070.4  44018.2    ...
# Cost of Production (`/Quintal) C2      2179.26  2127.35    ...
#
#                                                          39             40  \
# Crop                                   RAPESEED AND MUSTARD      SUGARCANE
# State                                               Haryana  Uttar Pradesh
# Cost of Cultivation (`/Hectare) A2+FL               14715.3        24538.3
# Cost of Cultivation (`/Hectare) C2                  27507.5        45239.5
# Cost of Production (`/Quintal) C2                   1251.12          93.64
#
#                                               41              42           43  \
# Crop                                   SUGARCANE       SUGARCANE    SUGARCANE
# State                                  Karnataka  Andhra Pradesh  Maharashtra
# Cost of Cultivation (`/Hectare) A2+FL    55655.4         56621.2      57673.6
# Cost of Cultivation (`/Hectare) C2       86765.8         91442.6      85801.9
# Cost of Production (`/Quintal) C2          86.53          119.72       107.56
#
#                                                44              45       46  \
# Crop                                    SUGARCANE           WHEAT    WHEAT
# State                                  Tamil Nadu  Madhya Pradesh   Punjab
# Cost of Cultivation (`/Hectare) A2+FL     66335.1         12464.4  17945.6
# Cost of Cultivation (`/Hectare) C2        89025.3         22489.8  35423.5
# Cost of Production (`/Quintal) C2           85.79          810.25    804.8
#
#                                                   47         48
# Crop                                           WHEAT      WHEAT
# State                                  Uttar Pradesh  Rajasthan
# Cost of Cultivation (`/Hectare) A2+FL        18979.4    19119.1
# Cost of Cultivation (`/Hectare) C2           31902.7    29876.4
# Cost of Production (`/Quintal) C2             769.84     683.58
#
# [5 rows x 49 columns]

# %%
# checking columns of dataframe 
display(cultivation_data.columns)
# creating list of specific columns from dataframe
columns = ['Crop', 'State', 'Yield (Quintal/ Hectare) ']
# creating subset of dataframe using list of specific columns
new_data = cultivation_data[columns]
# Out:
# Index([u'Crop', u'State', u'Cost of Cultivation (`/Hectare) A2+FL',
#        u'Cost of Cultivation (`/Hectare) C2',
#        u'Cost of Production (`/Quintal) C2', u'Yield (Quintal/ Hectare) ',
#        u'Per Hectare Cost Price', u'Cost of cultivation per hectare',
#        u'Yield in kg per hectare'],
#       dtype='object')

# %%
# pivoting the dataframe
table = new_data.pivot('Crop','State','Yield (Quintal/ Hectare) ')
# fill NaN values with zero 
table = table.fillna(0)
# plot(stacked bar plots) pivoted dataframe
table.plot(kind='bar', stacked=True)
table.plot(kind='bar', stacked=True)
plt.ylabel('Yield (Quintal/ Hectare) ')
plt.legend(loc='best')

# %%
# plotting transposed dataframe
#display(table.T)
table.T.plot(kind='bar',stacked=True)
table.T.plot(kind='bar',stacked=True)
plt.ylabel('Yield (Quintal/ Hectare) ')
#setting legend location to best
plt.legend(loc='best')

# %%
sns.heatmap(crops_prod_data, cmap='RdBu')

# %%
columns = ['Crop','State','Yield in kg per hectare']
new_data = cultivation_data[columns]

table = new_data.pivot('Crop','State','Yield in kg per hectare')
table = table.fillna(0)

ax = table.T.plot(kind='bar',stacked=True)
labels = []

for j in table.T.columns:
    for i in table.T.index:
        #values are added as factor to fit into plot
        label = round((int(table.T.loc[i][j])),1)
        labels.append(label)
        
patches = ax.patches

for label, rect in zip(labels, patches):
    width = rect.get_width()
    if width > 0:
        x = rect.get_x()
        y = rect.get_y()
        height = rect.get_height()
        ax.text(x + width/2.,y + height/2.,label,ha='center',va='center')
        
plt.ylabel('Yield (kg/ Hectare)')
plt.legend(loc='best')

# %%
columns = ['Crop','State','Per Hectare Cost Price']
new_data = cultivation_data[columns]

table = new_data.pivot('Crop','State','Per Hectare Cost Price')
table = table.fillna(0)
ax = table.T.plot(kind='bar',stacked=True)
labels = []
for j in table.T.columns:
    for i in table.T.index:
        label = round((int(table.T.loc[i][j])/10000),1)
        labels.append(label)
        
patches = ax.patches

for label, rect in zip(labels, patches):
    width =rect.get_width()
    if width > 0:
        x = rect.get_x()
        y = rect.get_y()
        height = rect.get_height()
        ax.text(x + width/2.,y + height/2.,label, ha='center', va='center')
        
plt.ylabel('Per Hectare Cost Price')

# %%
columns = ['Crop','State','Cost of cultivation per hectare']
new_data = cultivation_data[columns]

table = new_data.pivot('Crop','State','Cost of cultivation per hectare')
table = table.fillna(0)
ax = table.T.plot(kind='bar',stacked=True)
labels = []
for j in table.T.columns:
    for i in table.T.index:
        label = round((int(table.T.loc[i][j])/10000),1)
        labels.append(label)
        
patches = ax.patches

for label, rect in zip(labels, patches):
    width =rect.get_width()
    if width > 0:
        x = rect.get_x()
        y = rect.get_y()
        height = rect.get_height()
        ax.text(x + width/2.,y + height/2.,label, ha='center', va='center')
        
plt.ylabel('Cost of cultivation per hectare')

# %%
# now move to another dataset
crop_data = pd.read_csv("input/datafile (2).csv")
display(crop_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 16 columns):
# Crop                  55 non-null object
# Production 2006-07    55 non-null float64
# Production 2007-08    55 non-null float64
# Production 2008-09    55 non-null float64
# Production 2009-10    55 non-null float64
# Production 2010-11    55 non-null float64
# Area 2006-07          55 non-null float64
# Area 2007-08          55 non-null float64
# Area 2008-09          55 non-null float64
# Area 2009-10          55 non-null float64
# Area 2010-11          55 non-null float64
# Yield 2006-07         55 non-null float64
# Yield 2007-08         55 non-null float64
# Yield 2008-09         55 non-null float64
# Yield 2009-10         55 non-null float64
# Yield 2010-11         55 non-null float64
# dtypes: float64(15), object(1)
# memory usage: 6.9+ KB
# None

# %%
display(crop_data.columns)
# Out:
# Index([u'Crop             ', u'Production 2006-07', u'Production 2007-08',
#        u'Production 2008-09', u'Production 2009-10', u'Production 2010-11',
#        u'Area 2006-07', u'Area 2007-08', u'Area 2008-09', u'Area 2009-10',
#        u'Area 2010-11', u'Yield 2006-07', u'Yield 2007-08', u'Yield 2008-09',
#        u'Yield 2009-10', u'Yield 2010-11'],
#       dtype='object')

# %%
# formatting the space in Crop column
crop_data['Crop'] = crop_data['Crop             ']
del crop_data['Crop             ']
display(crop_data.columns)
# Out:
# Index([u'Production 2006-07', u'Production 2007-08', u'Production 2008-09',
#        u'Production 2009-10', u'Production 2010-11', u'Area 2006-07',
#        u'Area 2007-08', u'Area 2008-09', u'Area 2009-10', u'Area 2010-11',
#        u'Yield 2006-07', u'Yield 2007-08', u'Yield 2008-09', u'Yield 2009-10',
#        u'Yield 2010-11', u'Crop'],
#       dtype='object')

# %%
columns = ['Crop','Production 2006-07','Production 2007-08','Production 2008-09','Production 2009-10','Production 2010-11']
columns2 = ['Crop','Area 2006-07','Area 2007-08','Area 2008-09','Area 2009-10','Area 2010-11']
columns3 = ['Crop','Yield 2006-07','Yield 2007-08','Yield 2008-09','Yield 2009-10','Yield 2010-11']
production = crop_data[columns]
area = crop_data[columns2]
yd = crop_data[columns3]
display(production.head())
production.index = production['Crop']
area.index = area['Crop']
yd.index = yd['Crop']
del production['Crop']
del area['Crop']
del yd['Crop']
# Out:
#                Crop  Production 2006-07  Production 2007-08  \
# 0  Total Foodgrains               158.8               168.6
# 1              Rice               200.8               207.9
# 2             Wheat               131.6               136.4
# 3             Jowar               124.3               137.8
# 4             Bajra               136.4               161.5
#
#    Production 2008-09  Production 2009-10  Production 2010-11
# 0               171.3               159.4               178.9
# 1               213.3               191.6               206.4
# 2               140.1               140.3               150.8
# 3               126.0               116.5               121.8
# 4               143.9               105.4               167.9

# %%
# printing columns for transposed production dataframe 
display(production.T.columns)
# Out:
# Index([u'Total Foodgrains', u'Rice', u'Wheat', u'Jowar', u'Bajra', u'Maize',
#        u'Ragi', u'Small millets', u'Barley', u'Coarse Cereals', u'Cereals',
#        u'Gram', u'Arhar', u'Other Pulses', u'Total Pulses',
#        u'Total Non-Food grains ', u'Total Oilseeds', u'Groundnut', u'Sesamum',
#        u'Rapeseed &Mustard', u'Linseed', u'Castor seed', u'Safflower',
#        u'Niger seed', u'Sunflower', u'Soyabean', u'Nine Oilseeds', u'Coconut',
#        u'Cotton seed', u'Total Fibers', u'Cotton(lint)', u'Jute', u'Mesta',
#        u'Jute & Mesta', u'Sannhamp ', u'Tea ', u'Coffee ', u'Rubber ',
#        u'Total Spices', u'Black pepper', u'Dry chilies ', u'Dry ginger ',
#        u'Turmeric ', u'Arecanut  ', u'Cardamom ', u'Coriander', u'Garlic  ',
#        u'Total Fruits & Vegetables', u'Potato', u'Tapioca', u'Sweet potato  ',
#        u'Onion', u'Banana  ', u'Sugarcane', u'Tobacco'],
#       dtype='object', name=u'Crop')

# %%
# Get current size of figure 
fig_size = plt.rcParams["figure.figsize"]
print("Current size:", fig_size)

# Set figure width to 18 and height to 18
fig_size[0] = 18
fig_size[1] = 18
plt.rcParams["figure.figsize"] = fig_size

# initialize i for loop
i=0
ax = production.T.plot(subplots=True,layout=(11,5),colormap='tab20',label='Production',legend=False)
# for loop on axes for setting titles for subplots
for a in ax.flat:
    a.set_title(production.index[i])
    i += 1
    
#plotting another dataframes on same plot 
ax1 = area.T.plot(subplots=True,layout=(11,5),ax=ax, linestyle=':',marker='.',colormap='tab20b',legend=False)
ax2 = yd.T.plot(subplots=True,layout=(11,5),ax=ax, linestyle='--',marker='.',colormap='tab20c',legend=False)
labels = ['Production','Area','Yield']

# setting X-axis labels
plt.xticks(np.arange(5),('2006-07','2007-08','2008-09','2009-10','2010-11'))
# placing the legend on the bottom of plot 
plt.legend(labels=labels,loc='upper center', bbox_to_anchor=(-0.5, -0.5), shadow=True, ncol=3, fontsize = 'xx-large')
plt.tight_layout()
# Out:
# ('Current size:', [12.0, 9.0])
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_tools.py:204: UserWarning: When passing multiple axes, layout keyword is ignored
#   "ignored", UserWarning)

# %%
# These subplots above provide insights into how different crops production varies in relation to Yield 
# and area sown across India from 2006-07 to 2010-11. 
# Overall Total food grains, pulses,spices,non food grains,oilseeds,fruits and vegetables has increased from 
# 2006-07 to 2010-11
